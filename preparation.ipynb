# %% [markdown]
# # Preperation Process
# - Determining what needs to be prepped with the data
# - What needs to be prepped each time the project is recreated will go in the prepare.py file

# %%
import acquire
import prepare

import pandas as pd

# %%
df = acquire.get_churn_data()

# %%
# Transposing the first 5 columns of the data frame to see all columns with their data
df.head().T
# Out:
#                                        0                        1  \
# customer_id                   0003-MKNFE               0013-MHZWF
# gender                              Male                   Female
# senior_citizen                         0                        0
# partner                               No                       No
# dependents                            No                      Yes
# tenure                                 9                        9
# phone_service                        Yes                      Yes
# multiple_lines                       Yes                       No
# internet_service_type_id               1                        1
# online_security                       No                       No
# online_backup                         No                       No
# device_protection                     No                       No
# tech_support                          No                      Yes
# streaming_tv                          No                      Yes
# streaming_movies                     Yes                      Yes
# contract_type_id                       1                        1
# paperless_billing                     No                      Yes
# payment_type_id                        2                        4
# monthly_charges                     59.9                     69.4
# total_charges                      542.4                   571.45
# churn                                 No                       No
# contract_type             Month-to-month           Month-to-month
# payment_type                Mailed check  Credit card (automatic)
# internet_service_type                DSL                      DSL
#
#                                          2                 3  \
# customer_id                     0015-UOCOJ        0023-HGHWL
# gender                              Female              Male
# senior_citizen                           1                 1
# partner                                 No                No
# dependents                              No                No
# tenure                                   7                 1
# phone_service                          Yes                No
# multiple_lines                          No  No phone service
# internet_service_type_id                 1                 1
# online_security                        Yes                No
# online_backup                           No                No
# device_protection                       No                No
# tech_support                            No                No
# streaming_tv                            No                No
# streaming_movies                        No                No
# contract_type_id                         1                 1
# paperless_billing                      Yes               Yes
# payment_type_id                          1                 1
# monthly_charges                       48.2              25.1
# total_charges                       340.35              25.1
# churn                                   No               Yes
# contract_type               Month-to-month    Month-to-month
# payment_type              Electronic check  Electronic check
# internet_service_type                  DSL               DSL
#
#                                                   4
# customer_id                              0032-PGELS
# gender                                       Female
# senior_citizen                                    0
# partner                                         Yes
# dependents                                      Yes
# tenure                                            1
# phone_service                                    No
# multiple_lines                     No phone service
# internet_service_type_id                          1
# online_security                                 Yes
# online_backup                                    No
# device_protection                                No
# tech_support                                     No
# streaming_tv                                     No
# streaming_movies                                 No
# contract_type_id                                  1
# paperless_billing                                No
# payment_type_id                                   3
# monthly_charges                                30.5
# total_charges                                  30.5
# churn                                           Yes
# contract_type                        Month-to-month
# payment_type              Bank transfer (automatic)
# internet_service_type                           DSL

# %%
# First, check for duplicate observations
df.duplicated().sum()
# We do not have any duplicate rows
# Out:
# 0

# %% [markdown]
# # df.gender
# - creating dummy vars for gender

# %%
# We can see the variables for gender are strings, to use in explore and modeling we will convert to a dummy variable
df.gender.value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
# Creates a data frame of gender dummy variables, if male == 1
df_dummies = pd.get_dummies(df.gender, drop_first=True)

# Add to the original df
df = pd.concat([df, df_dummies],axis=1)

# Drop the column, we do not need the string version of gender
df = df.drop('gender', axis=1)

# Checking the df that it was added correctly
df.head()
# Out:
#   customer_id  senior_citizen partner dependents  tenure phone_service  \
# 0  0003-MKNFE               0      No         No       9           Yes
# 1  0013-MHZWF               0      No        Yes       9           Yes
# 2  0015-UOCOJ               1      No         No       7           Yes
# 3  0023-HGHWL               1      No         No       1            No
# 4  0032-PGELS               0     Yes        Yes       1            No
#
#      multiple_lines  internet_service_type_id online_security online_backup  \
# 0               Yes                         1              No            No
# 1                No                         1              No            No
# 2                No                         1             Yes            No
# 3  No phone service                         1              No            No
# 4  No phone service                         1             Yes            No
#
#    ... contract_type_id paperless_billing payment_type_id monthly_charges  \
# 0  ...                1                No               2            59.9
# 1  ...                1               Yes               4            69.4
# 2  ...                1               Yes               1            48.2
# 3  ...                1               Yes               1            25.1
# 4  ...                1                No               3            30.5
#
#    total_charges churn   contract_type               payment_type  \
# 0          542.4    No  Month-to-month               Mailed check
# 1         571.45    No  Month-to-month    Credit card (automatic)
# 2         340.35    No  Month-to-month           Electronic check
# 3           25.1   Yes  Month-to-month           Electronic check
# 4           30.5   Yes  Month-to-month  Bank transfer (automatic)
#
#   internet_service_type Male
# 0                   DSL    1
# 1                   DSL    0
# 2                   DSL    0
# 3                   DSL    1
# 4                   DSL    0
#
# [5 rows x 24 columns]

# %% [markdown]
# # Prepping columns with Yes/No to 1/0

# %%
# Going to replace Yes and No for any columns whose only value is Yes or No
# Ex: multiple lines includes yes, no, and no phone service
for column in df.columns:
    x = ['customer_id','tenure','monthly_charges','total_charges']
    if column in x:
        pass
    else:
        print("\n" + column)
        print(df[column].value_counts())
# Out:
# senior_citizen
# 0    5901
# 1    1142
# Name: senior_citizen, dtype: int64
#
# partner
# No     3641
# Yes    3402
# Name: partner, dtype: int64
#
# dependents
# No     4933
# Yes    2110
# Name: dependents, dtype: int64
#
# phone_service
# Yes    6361
# No      682
# Name: phone_service, dtype: int64
#
# multiple_lines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: multiple_lines, dtype: int64
#
# internet_service_type_id
# 2    3096
# 1    2421
# 3    1526
# Name: internet_service_type_id, dtype: int64
#
# online_security
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: online_security, dtype: int64
#
# online_backup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: online_backup, dtype: int64
#
# device_protection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: device_protection, dtype: int64
#
# tech_support
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: tech_support, dtype: int64
#
# streaming_tv
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: streaming_tv, dtype: int64
#
# streaming_movies
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: streaming_movies, dtype: int64
#
# contract_type_id
# 1    3875
# 3    1695
# 2    1473
# Name: contract_type_id, dtype: int64
#
# paperless_billing
# Yes    4171
# No     2872
# Name: paperless_billing, dtype: int64
#
# payment_type_id
# 1    2365
# 2    1612
# 3    1544
# 4    1522
# Name: payment_type_id, dtype: int64
#
# churn
# No     5174
# Yes    1869
# Name: churn, dtype: int64
#
# contract_type
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: contract_type, dtype: int64
#
# payment_type
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: payment_type, dtype: int64
#
# internet_service_type
# Fiber optic    3096
# DSL            2421
# None           1526
# Name: internet_service_type, dtype: int64
#
# Male
# 1    3555
# 0    3488
# Name: Male, dtype: int64

# %%
# Several columns are being represented by yes and no
# Going to replace Yes and No for any columns whose only value is Yes or No
# Ex: multiple lines includes yes, no, and no phone service
# Yes == 1, No == 0

df['partner'] = df['partner'].replace({'No': 0, 'Yes': 1})
df['dependents'] = df['dependents'].replace({'No': 0, 'Yes': 1})
df['phone_service'] = df['phone_service'].replace({'No': 0, 'Yes': 1})
df['paperless_billing'] = df['paperless_billing'].replace({'No': 0, 'Yes': 1})
df['churn'] = df['churn'].replace({'No': 0, 'Yes': 1})

df.head().T
# Out:
#                                        0                        1  \
# customer_id                   0003-MKNFE               0013-MHZWF
# senior_citizen                         0                        0
# partner                                0                        0
# dependents                             0                        1
# tenure                                 9                        9
# phone_service                          1                        1
# multiple_lines                       Yes                       No
# internet_service_type_id               1                        1
# online_security                       No                       No
# online_backup                         No                       No
# device_protection                     No                       No
# tech_support                          No                      Yes
# streaming_tv                          No                      Yes
# streaming_movies                     Yes                      Yes
# contract_type_id                       1                        1
# paperless_billing                      0                        1
# payment_type_id                        2                        4
# monthly_charges                     59.9                     69.4
# total_charges                      542.4                   571.45
# churn                                  0                        0
# contract_type             Month-to-month           Month-to-month
# payment_type                Mailed check  Credit card (automatic)
# internet_service_type                DSL                      DSL
# Male                                   1                        0
#
#                                          2                 3  \
# customer_id                     0015-UOCOJ        0023-HGHWL
# senior_citizen                           1                 1
# partner                                  0                 0
# dependents                               0                 0
# tenure                                   7                 1
# phone_service                            1                 0
# multiple_lines                          No  No phone service
# internet_service_type_id                 1                 1
# online_security                        Yes                No
# online_backup                           No                No
# device_protection                       No                No
# tech_support                            No                No
# streaming_tv                            No                No
# streaming_movies                        No                No
# contract_type_id                         1                 1
# paperless_billing                        1                 1
# payment_type_id                          1                 1
# monthly_charges                       48.2              25.1
# total_charges                       340.35              25.1
# churn                                    0                 1
# contract_type               Month-to-month    Month-to-month
# payment_type              Electronic check  Electronic check
# internet_service_type                  DSL               DSL
# Male                                     0                 1
#
#                                                   4
# customer_id                              0032-PGELS
# senior_citizen                                    0
# partner                                           1
# dependents                                        1
# tenure                                            1
# phone_service                                     0
# multiple_lines                     No phone service
# internet_service_type_id                          1
# online_security                                 Yes
# online_backup                                    No
# device_protection                                No
# tech_support                                     No
# streaming_tv                                     No
# streaming_movies                                 No
# contract_type_id                                  1
# paperless_billing                                 0
# payment_type_id                                   3
# monthly_charges                                30.5
# total_charges                                  30.5
# churn                                             1
# contract_type                        Month-to-month
# payment_type              Bank transfer (automatic)
# internet_service_type                           DSL
# Male                                              0

# %% [markdown]
# # Tenure
# - renaming tenure column to specify months, creating column for tenure in months

# %%
# Renaming tenure to tenure_months before creating a tenure_years column
df = df.rename(columns = {'tenure':'tenure_months'})
df.head(1).T
# Out:
#                                        0
# customer_id                   0003-MKNFE
# senior_citizen                         0
# partner                                0
# dependents                             0
# tenure_months                          9
# phone_service                          1
# multiple_lines                       Yes
# internet_service_type_id               1
# online_security                       No
# online_backup                         No
# device_protection                     No
# tech_support                          No
# streaming_tv                          No
# streaming_movies                     Yes
# contract_type_id                       1
# paperless_billing                      0
# payment_type_id                        2
# monthly_charges                     59.9
# total_charges                      542.4
# churn                                  0
# contract_type             Month-to-month
# payment_type                Mailed check
# internet_service_type                DSL
# Male                                   1

# %%
# Creating a new feature, tenure in years, by dividing tenure in months by 12
df['tenure_years'] = round(df.tenure_months / 12, 2)
df.head(1)
# Out:
#   customer_id  senior_citizen  partner  dependents  tenure_months  \
# 0  0003-MKNFE               0        0           0              9
#
#    phone_service multiple_lines  internet_service_type_id online_security  \
# 0              1            Yes                         1              No
#
#   online_backup  ... paperless_billing payment_type_id monthly_charges  \
# 0            No  ...                 0               2            59.9
#
#   total_charges  churn   contract_type  payment_type  internet_service_type  \
# 0         542.4      0  Month-to-month  Mailed check                    DSL
#
#   Male  tenure_years
# 0    1          0.75
#
# [1 rows x 25 columns]

# %%
# A look at the data types for charges shows us only monthly is a float
df.monthly_charges.dtypes, df.total_charges.dtypes
# Out:
# (dtype('float64'), dtype('O'))

# %%
# the following code checks if all numbers in total_charges can be converted to ints
# we can only convert the number if the string has only digits, decimals, and commas
# there are 11 observations where it has more than this
numbers = set('0123456789.,')
count = 0
for x in df.total_charges:
    for y in x:
        if y not in numbers:
            count += 1
print(count)
# Out:
# 11

# %%
# could be that the 11 observations have leading or trailing white space
df['total_charges'] = df.total_charges.str.strip()

# %%
# still does not convert to float
# df.astype({'total_charges':'float64'})
#gives an error

# %%
# let's take a different approach to finding the values that are not converting
df.total_charges.sort_values(ascending=True)
# we can see there are observations with no value
# Out:
# 2048
# 6143
# 1949
# 1878
# 6615
#          ...
# 6341    997.75
# 6261     998.1
# 3702    999.45
# 3392     999.8
# 4349     999.9
# Name: total_charges, Length: 7043, dtype: object

# %%
# There are 11 customers with no tenure and therefore no total_charges 
# They also have 0 as churn, aka they are still with the company but have not been charged yet
df[df.tenure_months == 0]
# Out:
#      customer_id  senior_citizen  partner  dependents  tenure_months  \
# 1878  1371-DWPAZ               0        1           1              0
# 1949  2775-SEFEE               0        0           1              0
# 2029  4075-WKNIU               0        1           1              0
# 2048  4472-LVYGI               0        1           1              0
# 2132  5709-LVOEQ               0        1           1              0
# 6143  2923-ARZLG               0        1           1              0
# 6569  2520-SGTTA               0        1           1              0
# 6605  3115-CZMZD               0        0           1              0
# 6615  3213-VVOLG               0        1           1              0
# 6686  4367-NUYAO               0        1           1              0
# 6895  7644-OMVMY               0        1           1              0
#
#       phone_service    multiple_lines  internet_service_type_id  \
# 1878              0  No phone service                         1
# 1949              1               Yes                         1
# 2029              1               Yes                         1
# 2048              0  No phone service                         1
# 2132              1                No                         1
# 6143              1                No                         3
# 6569              1                No                         3
# 6605              1                No                         3
# 6615              1               Yes                         3
# 6686              1               Yes                         3
# 6895              1                No                         3
#
#           online_security        online_backup  ... paperless_billing  \
# 1878                  Yes                  Yes  ...                 0
# 1949                  Yes                  Yes  ...                 1
# 2029                   No                  Yes  ...                 0
# 2048                  Yes                   No  ...                 1
# 2132                  Yes                  Yes  ...                 0
# 6143  No internet service  No internet service  ...                 1
# 6569  No internet service  No internet service  ...                 0
# 6605  No internet service  No internet service  ...                 0
# 6615  No internet service  No internet service  ...                 0
# 6686  No internet service  No internet service  ...                 0
# 6895  No internet service  No internet service  ...                 0
#
#      payment_type_id monthly_charges total_charges  churn  contract_type  \
# 1878               4           56.05                    0       Two year
# 1949               3           61.90                    0       Two year
# 2029               2           73.35                    0       Two year
# 2048               3           52.55                    0       Two year
# 2132               2           80.85                    0       Two year
# 6143               2           19.70                    0       One year
# 6569               2           20.00                    0       Two year
# 6605               2           20.25                    0       Two year
# 6615               2           25.35                    0       Two year
# 6686               2           25.75                    0       Two year
# 6895               2           19.85                    0       Two year
#
#                    payment_type  internet_service_type Male  tenure_years
# 1878    Credit card (automatic)                    DSL    0           0.0
# 1949  Bank transfer (automatic)                    DSL    1           0.0
# 2029               Mailed check                    DSL    0           0.0
# 2048  Bank transfer (automatic)                    DSL    0           0.0
# 2132               Mailed check                    DSL    0           0.0
# 6143               Mailed check                   None    1           0.0
# 6569               Mailed check                   None    0           0.0
# 6605               Mailed check                   None    1           0.0
# 6615               Mailed check                   None    1           0.0
# 6686               Mailed check                   None    1           0.0
# 6895               Mailed check                   None    1           0.0
#
# [11 rows x 25 columns]

# %%
# let's replace empty values with 0
# where function replaces when the conditional statement is false with the value specified
df['total_charges'] = df.total_charges.where((df.tenure_months != 0),0)

#check it worked
df[df.tenure_months == 0]
# Out:
#      customer_id  senior_citizen  partner  dependents  tenure_months  \
# 1878  1371-DWPAZ               0        1           1              0
# 1949  2775-SEFEE               0        0           1              0
# 2029  4075-WKNIU               0        1           1              0
# 2048  4472-LVYGI               0        1           1              0
# 2132  5709-LVOEQ               0        1           1              0
# 6143  2923-ARZLG               0        1           1              0
# 6569  2520-SGTTA               0        1           1              0
# 6605  3115-CZMZD               0        0           1              0
# 6615  3213-VVOLG               0        1           1              0
# 6686  4367-NUYAO               0        1           1              0
# 6895  7644-OMVMY               0        1           1              0
#
#       phone_service    multiple_lines  internet_service_type_id  \
# 1878              0  No phone service                         1
# 1949              1               Yes                         1
# 2029              1               Yes                         1
# 2048              0  No phone service                         1
# 2132              1                No                         1
# 6143              1                No                         3
# 6569              1                No                         3
# 6605              1                No                         3
# 6615              1               Yes                         3
# 6686              1               Yes                         3
# 6895              1                No                         3
#
#           online_security        online_backup  ... paperless_billing  \
# 1878                  Yes                  Yes  ...                 0
# 1949                  Yes                  Yes  ...                 1
# 2029                   No                  Yes  ...                 0
# 2048                  Yes                   No  ...                 1
# 2132                  Yes                  Yes  ...                 0
# 6143  No internet service  No internet service  ...                 1
# 6569  No internet service  No internet service  ...                 0
# 6605  No internet service  No internet service  ...                 0
# 6615  No internet service  No internet service  ...                 0
# 6686  No internet service  No internet service  ...                 0
# 6895  No internet service  No internet service  ...                 0
#
#      payment_type_id monthly_charges total_charges  churn  contract_type  \
# 1878               4           56.05             0      0       Two year
# 1949               3           61.90             0      0       Two year
# 2029               2           73.35             0      0       Two year
# 2048               3           52.55             0      0       Two year
# 2132               2           80.85             0      0       Two year
# 6143               2           19.70             0      0       One year
# 6569               2           20.00             0      0       Two year
# 6605               2           20.25             0      0       Two year
# 6615               2           25.35             0      0       Two year
# 6686               2           25.75             0      0       Two year
# 6895               2           19.85             0      0       Two year
#
#                    payment_type  internet_service_type Male  tenure_years
# 1878    Credit card (automatic)                    DSL    0           0.0
# 1949  Bank transfer (automatic)                    DSL    1           0.0
# 2029               Mailed check                    DSL    0           0.0
# 2048  Bank transfer (automatic)                    DSL    0           0.0
# 2132               Mailed check                    DSL    0           0.0
# 6143               Mailed check                   None    1           0.0
# 6569               Mailed check                   None    0           0.0
# 6605               Mailed check                   None    1           0.0
# 6615               Mailed check                   None    1           0.0
# 6686               Mailed check                   None    1           0.0
# 6895               Mailed check                   None    1           0.0
#
# [11 rows x 25 columns]

# %%
# Converting to float now works without 
df = df.astype({'total_charges':'float64'})

# %%
# Can also use dtypes to double check
df.dtypes
# Out:
# customer_id                  object
# senior_citizen                int64
# partner                       int64
# dependents                    int64
# tenure_months                 int64
# phone_service                 int64
# multiple_lines               object
# internet_service_type_id      int64
# online_security              object
# online_backup                object
# device_protection            object
# tech_support                 object
# streaming_tv                 object
# streaming_movies             object
# contract_type_id              int64
# paperless_billing             int64
# payment_type_id               int64
# monthly_charges             float64
# total_charges               float64
# churn                         int64
# contract_type                object
# payment_type                 object
# internet_service_type        object
# Male                          uint8
# tenure_years                float64
# dtype: object
